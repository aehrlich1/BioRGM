# %%
# Load a model with pre-trained weights and produce embedding values
from src.pretrain import Pretrain
from torch_geometric.utils.smiles import from_smiles

# %%
pretrain = Pretrain(data_dir="../data")
# pretrain.load_random_model(64, 0.2)
pretrain.load_pretrained_model("robust-feather-8")

data = from_smiles("CCCC=O")
pretrain.model.eval()
print(pretrain.model(data))
# Out:
# tensor([[0.0000, 0.0000, 0.0098, 0.1035, 0.0000, 0.0078, 0.0088, 0.0882, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1256, 0.0151, 0.0000, 0.0000,
#          0.0026, 0.0000, 0.0000, 0.0162, 0.0000, 0.3530, 0.0185, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.2747, 0.1452, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0011, 0.0000, 0.0000, 0.0290, 0.0037, 0.0000, 0.0000, 0.1527, 0.0000,
#          0.0000, 0.1179, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0939,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1029, 0.0000, 0.0630, 0.1942,
#          0.0622, 0.0000, 0.0000, 0.0000, 0.0287, 0.0000, 0.0000, 0.0000, 0.0298,
#          0.0000, 0.0805, 0.0000, 0.4657, 0.0000, 0.0000, 0.0000, 0.0000, 0.0057,
#          0.0000, 0.3970, 0.0401, 0.0000, 0.0019, 0.0000, 0.1088, 0.0000, 0.0012,
# ...
